# %%
from mtcnn.mtcnn import MTCNN 
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import tensorflow.keras as keras
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
#function for extraction of faces
def extract_face(path , required_size = (160 ,160)):
    #load image from file
    
    img = Image.open(path)
    #convert to RGB
    img = img.convert('RGB')
    #convert to array
    pixels = np.asarray(img)
    #create detector 
    detector = MTCNN()
    result= detector.detect_faces(pixels)
    #extract face
    x1,y1,width,height = result[0]['box']
    x1 , y1 = abs(x1) , abs(y1)
    x2 , y2 = x1 + width , y1 + height
    face = pixels[y1:y2 , x1: x2]
    #resize
    img = Image.fromarray(face)
    img = img.resize((160 , 160))
    face_array = np.asarray(img)
    return face_array

# %%
#extract for all images in directory
def load_faces(directory):
    faces = list()
    for filename in listdir(directory):
        path = directory +filename
        face = extract_face(path)
        faces.append(face)
    return faces

# %%
#load dataset from all folders
def load_dataset(directory):
    X , y = list(), list()
    for subdir in listdir(directory):
        path = directory + subdir + '\\'
        #if not  subdir(path):
            #continue
        faces = load_faces(path)
        labels =[subdir for _ in range(len(faces))]
        print('>loaded %d examples for class: %s' % (len(faces), subdir))
        X.extend(faces)
        y.extend(labels)
    return np.asarray(X) , np.asarray(y)

# %%
#load training dataset 
X_train , Y_train = load_dataset(r'D:\FaceDataset\train\\')
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B708954700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#load validation dataset 
X_test , Y_test = load_dataset(r'D:\FaceDataset\val\\')
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B70FAC9B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
# save arrays to one file in compressed format
np.savez_compressed(r'D:\FaceDataset\data.npz', X_train, Y_train, X_test, Y_test)

# %%
# # building the input vector from the 32x32 pixels
X_train = X_train.reshape(X_train.shape[0], 160, 160, 3)
X_test = X_test.reshape(X_test.shape[0], 160,160, 3)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalizing the data to help with the training
X_train /= 255
X_test /= 255

# %%
n_classes = 5
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = pd.get_dummies(y_train)
Y_test = pd.get_dummies(y_test)
print("Shape after one-hot encoding: ", Y_train.shape)
# Out:
# Shape before one-hot encoding:  (93,)
# Shape after one-hot encoding:  (93, 5)

# %%
# label encode targets
out_encoder = LabelEncoder()
out_encoder.fit(Y_train)
Y_train = out_encoder.transform(Y_train)
Y_test = out_encoder.transform(Y_test)

# %%
n_classes = 5
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = pd.get_dummies(y_train)
Y_test = pd.get_dummies(y_test)
print("Shape after one-hot encoding: ", Y_train.shape)

# %%
# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=100, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 1.6108 - accuracy: 0.2043 - val_loss: 8.4884 - val_accuracy: 0.2000
# Epoch 2/100
# 1/1 [==============================] - 3s 3s/step - loss: 11.9698 - accuracy: 0.1828 - val_loss: 3.2870 - val_accuracy: 0.2000
# Epoch 3/100
# 1/1 [==============================] - 3s 3s/step - loss: 6.5133 - accuracy: 0.1720 - val_loss: 1.6607 - val_accuracy: 0.2000
# Epoch 4/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.1622 - accuracy: 0.2258 - val_loss: 1.6140 - val_accuracy: 0.2000
# Epoch 5/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6676 - accuracy: 0.2581 - val_loss: 1.6016 - val_accuracy: 0.2000
# Epoch 6/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6068 - accuracy: 0.2043 - val_loss: 1.6022 - val_accuracy: 0.2000
# Epoch 7/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6246 - accuracy: 0.1613 - val_loss: 1.6044 - val_accuracy: 0.4400
# ...

# %% [markdown]
# # Performance

# %%
# predict maddona image downloaded
test_img = r'D:\FaceDataset\madd.jpg'
face = extract_face(test_img)
face = np.asarray(face)
face = face.reshape(1, 160, 160, 3)
face = face.astype('float32')
y_hat = model.predict(face)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B764A4C160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
y_hat # correctly classifing as moddona
# Out:
# array([[0., 0., 0., 1., 0.]], dtype=float32)
